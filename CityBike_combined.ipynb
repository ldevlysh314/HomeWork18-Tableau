# %%
import pandas as pd

# %%
# Data files to be combined 
files23 = ['data/JC-202310-citibike-tripdata.csv', 'data/JC-202311-citibike-tripdata.csv', 'data/JC-202312-citibike-tripdata.csv']

# Empty list to store each dataframe
df23_list = []

# Loop through each file in the list
for file in files23:
    # Read the file into a dataframe
    df23 = pd.read_csv(file)

    # Append the dataframe to the list
    df23_list.append(df23)

# Concatenate all dataframes in the list into one dataframe
df23 = pd.concat(df23_list)

# Show dataframe
df23
# Out:
#                 ride_id rideable_type           started_at  \
# 0      56269E94B2206375  classic_bike  2023-10-31 11:52:42
# 1      2B2F6514026F5C68  classic_bike  2023-10-16 08:24:33
# 2      3716C0E2166FE548  classic_bike  2023-10-21 11:46:26
# 3      E06BF0A228598DDF  classic_bike  2023-10-26 09:42:42
# 4      1EA3E3FFB17B6B16  classic_bike  2023-10-22 13:20:54
# ...                 ...           ...                  ...
# 58675  7E862701EE7A6A03  classic_bike  2023-12-20 17:55:41
# 58676  DFAF91AB91BE25DB  classic_bike  2023-12-13 14:36:43
# 58677  AEE7B49E6EDFAE6F  classic_bike  2023-12-18 16:40:00
# 58678  A38E98956AD72EFB  classic_bike  2023-12-02 13:42:51
# 58679  F16E0B969D877368  classic_bike  2023-12-19 16:30:13
#
#                   ended_at start_station_name start_station_id  \
# 0      2023-10-31 12:03:33    McGinley Square            JC055
# 1      2023-10-16 08:35:28        Astor Place            JC077
# 2      2023-10-21 11:56:30    McGinley Square            JC055
# ...

# %%
# Save the dataframe to a CSV file
df23.to_csv('data/citibike23.csv', index=False)
